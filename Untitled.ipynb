# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv(r"C:\Users\yamti\Downloads\30af8da4-7586-4b00-ac88-c5ee75251632.csv", encoding="utf-8")

# %% [markdown]
# # Exploratory data analysis

# %%
df.head()
# Out:
#    alina_id                        website  \
# 0         1                            NaN
# 1         3                            NaN
# 2         5                            NaN
# 3         7  https://ofaqimindustry.co.il/
# 4        11                            NaN
#
#                                    alina_description  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3  <p>העיר אופקים נמצאת במחוז דרום, כאשר אזור התע...
# 4                                                NaN
#
#                                alina_description_eng   alina_name  \
# 0                                                NaN   אבו קרינאת
# 1                                                NaN       אבשלום
# 2                                                NaN  אום אל חנוכ
# 3  <p>The city Ofakim is situated in the southern...       אופקים
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 59 entries, 0 to 58
# Data columns (total 22 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   alina_id               59 non-null     int64
#  1   website                18 non-null     object
#  2   alina_description      18 non-null     object
#  3   alina_description_eng  18 non-null     object
#  4   alina_name             59 non-null     object
#  5   alina_eng_name         59 non-null     object
#  6   district               57 non-null     object
#  7   district_en            57 non-null     object
#  8   available_space        59 non-null     int64
#  9   occupied_space         59 non-null     int64
#  10  future_employees       59 non-null     int64
#  11  current_employees      59 non-null     int64
#  12  open_to_market         59 non-null     bool
#  13  geom                   47 non-null     object
# ...

# %%
df.columns
# Out:
# Index(['alina_id', 'website', 'alina_description', 'alina_description_eng',
#        'alina_name', 'alina_eng_name', 'district', 'district_en',
#        'available_space', 'occupied_space', 'future_employees',
#        'current_employees', 'open_to_market', 'geom', 'contact_name',
#        'contact_role', 'contact_email', 'contact_phone', 'contact_mobile',
#        'small_factories', 'medium_factories', 'big_factories'],
#       dtype='object')

# %%
# Understanding which district has the most industrial parks.

df_groupby_district = df[["alina_id", "district"]].groupby("district").count().reset_index()

df_groupby_district.rename(columns = {"alina_id":"id_count"} ,inplace=True)

# Reversing the hebrew string so they will be presented properly.
df_groupby_district["district"] = df_groupby_district["district"].apply(lambda x: x[::-1])



# Choosing the most generic way to do that calculate how many colors and explode amount I need to get:
def generate_color():
    colors = ["bisque", "palegoldenrod", "darkseagreen", "burlywood", "tan"]
    for color in colors:
        yield color

gen = generate_color()


# Defining colors for the pie chart
colors = [next(gen) for x in range(len(list(set(df["district"].dropna()))))]


# Define the ratio of gap of each fragment in a tuple
explode = [0.05 for x in range(len(list(set(df["district"].dropna()))))]

fig, ax = plt.subplots()
df_groupby_district.plot(kind= "pie", y="id_count",x="district",
  autopct="%1.0f%%", colors=colors, explode=explode, ax=ax,
    labels =list(set(df["district"].dropna().apply(lambda x: x[::-1])))
                        )

ax.legend(list(set(df["district"].dropna().apply(lambda x: x[::-1]))))

# %%
df_groupby_district
# Out:
#      district  id_count
# 0        םורד        29
# 1   ןופצ-הפיח        12
# 2        ש"וי         6
# 3     םילשורי         7
# 4  זכרמהו א"ת         3
